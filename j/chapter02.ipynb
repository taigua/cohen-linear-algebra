# %% [markdown]
# # CHAPTER: Vectors (chapter 2)
# ## Code

# %%
NB. Load packages
load 'plot'
load 'stats/base/random'

# %% [markdown]
# ### Section 2.1, code block 2.1

# %%
aScalar =: 4

# %% [markdown]
# ### Section 2.2, code block 2.3

# %%
'aspect 1; xrange _3 3; yrange _3 3' plot 0 2; 0 _1
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset=utf-8>
# 	<title>J Plot</title>
# 	<style>
# 		#canvas1{margin-left:0; margin-top:0;}
# 	</style>
#
#   <!--[if lt IE 9]><script src="/~addons/ide/jhs/js/excanvas.js" type="text/javascript"></script><![endif]-->
# 	<script type="text/javascript">
# 		function graph() {
# 			var graphCanvas = document.getElementById('canvas1');
# 			// ensure that the element is available within the DOM
# 			if (graphCanvas && graphCanvas.getContext) {
# 				// open a 2D context within the canvas
# 				var context = graphCanvas.getContext('2d');
# 				// draw
# 				drawPlot(context);
# 			}
# 		}
#
# function drawPlot(ctx) {
# ctx.beginPath(); ctx.moveTo(0,200)  ; ctx.lineTo(0,0)    ; ctx.lineTo(400,0)  ; ctx.lineTo(400,200); ctx.lineTo(0,200)  ;ctx.fillStyle= "rgb(255,255,255)";ctx.strokeStyle= "rgb(255,255,255)";ctx.lineWidth="1";ctx.stroke();ctx.fill();ctx.closePath();
# ctx.strokeStyle= "rgb(0,0,0)";ctx.lineWidth="1";
# ctx.beginPath();ctx.moveTo(115,181);ctx.lineTo(285,181);ctx.lineTo(285,11) ;ctx.lineTo(115,11) ;ctx.lineTo(115,181);ctx.stroke();ctx.closePath();
# ctx.strokeStyle= "rgb(192,192,192)";ctx.lineWidth="1";
# ctx.beginPath();ctx.moveTo(124,172)    ;ctx.lineTo(125,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(127,172)    ;ctx.lineTo(128,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(130,172)    ;ctx.lineTo(131,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(133,172)    ;ctx.lineTo(134,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(136,172)    ;ctx.lineTo(137,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(139,172)    ;ctx.lineTo(140,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(142,172)    ;ctx.lineTo(143,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(145,172)    ;ctx.lineTo(146,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(148,172)    ;ctx.lineTo(149,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(151,172)    ;ctx.lineTo(152,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(154,172)    ;ctx.lineTo(155,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(157,172)    ;ctx.lineTo(158,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(160,172)    ;ctx.lineTo(161,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(163,172)    ;ctx.lineTo(164,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(166,172)    ;ctx.lineTo(167,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(169,172)    ;ctx.lineTo(170,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(172,172)    ;ctx.lineTo(173,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(175,172)    ;ctx.lineTo(176,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(178,172)    ;ctx.lineTo(179,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(181,172)    ;ctx.lineTo(182,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(184,172)    ;ctx.lineTo(185,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(187,172)    ;ctx.lineTo(188,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(190,172)    ;ctx.lineTo(191,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(193,172)    ;ctx.lineTo(194,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(196,172)    ;ctx.lineTo(197,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(199,172)    ;ctx.lineTo(200,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(202,172)    ;ctx.lineTo(203,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(205,172)    ;ctx.lineTo(206,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(208,172)    ;ctx.lineTo(209,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(211,172)    ;ctx.lineTo(212,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(214,172)    ;ctx.lineTo(215,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(217,172)    ;ctx.lineTo(218,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(220,172)    ;ctx.lineTo(221,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(223,172)    ;ctx.lineTo(224,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(226,172)    ;ctx.lineTo(227,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(229,172)    ;ctx.lineTo(230,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(232,172)    ;ctx.lineTo(233,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(235,172)    ;ctx.lineTo(236,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(238,172)    ;ctx.lineTo(239,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(241,172)    ;ctx.lineTo(242,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(244,172)    ;ctx.lineTo(245,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(247,172)    ;ctx.lineTo(248,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(250,172)    ;ctx.lineTo(251,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(253,172)    ;ctx.lineTo(254,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(256,172)    ;ctx.lineTo(257,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(259,172)    ;ctx.lineTo(260,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(262,172)    ;ctx.lineTo(263,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(265,172)    ;ctx.lineTo(266,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(268,172)    ;ctx.lineTo(269,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(271,172)    ;ctx.lineTo(272,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(274,172)    ;ctx.lineTo(275,172)    ;ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(124,146.667);ctx.lineTo(125,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(127,146.667);ctx.lineTo(128,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(130,146.667);ctx.lineTo(131,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(133,146.667);ctx.lineTo(134,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(136,146.667);ctx.lineTo(137,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(139,146.667);ctx.lineTo(140,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(142,146.667);ctx.lineTo(143,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(145,146.667);ctx.lineTo(146,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(148,146.667);ctx.lineTo(149,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(151,146.667);ctx.lineTo(152,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(154,146.667);ctx.lineTo(155,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(157,146.667);ctx.lineTo(158,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(160,146.667);ctx.lineTo(161,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(163,146.667);ctx.lineTo(164,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(166,146.667);ctx.lineTo(167,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(169,146.667);ctx.lineTo(170,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(172,146.667);ctx.lineTo(173,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(175,146.667);ctx.lineTo(176,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(178,146.667);ctx.lineTo(179,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(181,146.667);ctx.lineTo(182,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(184,146.667);ctx.lineTo(185,146.667);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(187,146.667);ctx.lineTo(188,146.667);ctx.stroke();ctx.closePath();
# ctx.

# %% [markdown]
# ### Section 2.2, code block 2.5

# %%
NB. list, vector
v1 =: 2 4 5 7

NB. row array
v2 =: 1 4 $ 2 4 5 7

NB. col array
v3 =: 4 1 $ 2 4 5 7

# %% [markdown]
# ### Section 2.3, code block 2.7

# %%
NB. row vector
v1 =: 2 4 5 7

NB. change vector to col array
v2 =: ,. v1

NB. row array
v3 =: 1 4 $ 2 4 5 7

NB. col array
v4 =: |: v3

# %% [markdown]
# ### Section 2.5, code block 2.9

# %%
v1 =: 2 5 4 7
v2 =: 4 1 0 2

v3 =: (4*v1) - 2*v2
v3
# Out:
# 0 18 16 24

# %% [markdown]
# ## Code challenges

# %% [markdown]
# ### Challenge 1

# %%
v =: 1 2
r =: normalrand 10
v =: v , v *"1 0 r
'aspect 1; xrange _4 4; yrange _4 4' plot ;/ 0 ,"0 |: v
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset=utf-8>
# 	<title>J Plot</title>
# 	<style>
# 		#canvas2{margin-left:0; margin-top:0;}
# 	</style>
#
#   <!--[if lt IE 9]><script src="/~addons/ide/jhs/js/excanvas.js" type="text/javascript"></script><![endif]-->
# 	<script type="text/javascript">
# 		function graph() {
# 			var graphCanvas = document.getElementById('canvas2');
# 			// ensure that the element is available within the DOM
# 			if (graphCanvas && graphCanvas.getContext) {
# 				// open a 2D context within the canvas
# 				var context = graphCanvas.getContext('2d');
# 				// draw
# 				drawPlot(context);
# 			}
# 		}
#
# function drawPlot(ctx) {
# ctx.beginPath(); ctx.moveTo(0,200)  ; ctx.lineTo(0,0)    ; ctx.lineTo(400,0)  ; ctx.lineTo(400,200); ctx.lineTo(0,200)  ;ctx.fillStyle= "rgb(255,255,255)";ctx.strokeStyle= "rgb(255,255,255)";ctx.lineWidth="1";ctx.stroke();ctx.fill();ctx.closePath();
# ctx.strokeStyle= "rgb(0,0,0)";ctx.lineWidth="1";
# ctx.beginPath();ctx.moveTo(115,181);ctx.lineTo(285,181);ctx.lineTo(285,11) ;ctx.lineTo(115,11) ;ctx.lineTo(115,181);ctx.stroke();ctx.closePath();
# ctx.strokeStyle= "rgb(192,192,192)";ctx.lineWidth="1";
# ctx.beginPath();ctx.moveTo(124,172);ctx.lineTo(125,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(127,172);ctx.lineTo(128,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(130,172);ctx.lineTo(131,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(133,172);ctx.lineTo(134,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(136,172);ctx.lineTo(137,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(139,172);ctx.lineTo(140,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(142,172);ctx.lineTo(143,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(145,172);ctx.lineTo(146,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(148,172);ctx.lineTo(149,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(151,172);ctx.lineTo(152,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(154,172);ctx.lineTo(155,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(157,172);ctx.lineTo(158,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(160,172);ctx.lineTo(161,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(163,172);ctx.lineTo(164,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(166,172);ctx.lineTo(167,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(169,172);ctx.lineTo(170,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(172,172);ctx.lineTo(173,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(175,172);ctx.lineTo(176,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(178,172);ctx.lineTo(179,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(181,172);ctx.lineTo(182,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(184,172);ctx.lineTo(185,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(187,172);ctx.lineTo(188,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(190,172);ctx.lineTo(191,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(193,172);ctx.lineTo(194,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(196,172);ctx.lineTo(197,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(199,172);ctx.lineTo(200,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(202,172);ctx.lineTo(203,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(205,172);ctx.lineTo(206,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(208,172);ctx.lineTo(209,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(211,172);ctx.lineTo(212,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(214,172);ctx.lineTo(215,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(217,172);ctx.lineTo(218,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(220,172);ctx.lineTo(221,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(223,172);ctx.lineTo(224,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(226,172);ctx.lineTo(227,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(229,172);ctx.lineTo(230,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(232,172);ctx.lineTo(233,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(235,172);ctx.lineTo(236,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(238,172);ctx.lineTo(239,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(241,172);ctx.lineTo(242,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(244,172);ctx.lineTo(245,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(247,172);ctx.lineTo(248,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(250,172);ctx.lineTo(251,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(253,172);ctx.lineTo(254,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(256,172);ctx.lineTo(257,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(259,172);ctx.lineTo(260,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(262,172);ctx.lineTo(263,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(265,172);ctx.lineTo(266,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(268,172);ctx.lineTo(269,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(271,172);ctx.lineTo(272,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(274,172);ctx.lineTo(275,172);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(124,134);ctx.lineTo(125,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(127,134);ctx.lineTo(128,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(130,134);ctx.lineTo(131,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(133,134);ctx.lineTo(134,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(136,134);ctx.lineTo(137,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(139,134);ctx.lineTo(140,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(142,134);ctx.lineTo(143,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(145,134);ctx.lineTo(146,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(148,134);ctx.lineTo(149,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(151,134);ctx.lineTo(152,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(154,134);ctx.lineTo(155,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(157,134);ctx.lineTo(158,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(160,134);ctx.lineTo(161,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(163,134);ctx.lineTo(164,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(166,134);ctx.lineTo(167,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(169,134);ctx.lineTo(170,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(172,134);ctx.lineTo(173,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(175,134);ctx.lineTo(176,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(178,134);ctx.lineTo(179,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(181,134);ctx.lineTo(182,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(184,134);ctx.lineTo(185,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(187,134);ctx.lineTo(188,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(190,134);ctx.lineTo(191,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(193,134);ctx.lineTo(194,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(196,134);ctx.lineTo(197,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(199,134);ctx.lineTo(200,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(202,134);ctx.lineTo(203,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(205,134);ctx.lineTo(206,134);ctx.stroke();ctx.closePath();
# ctx.beginPath();ctx.moveTo(208,134);ctx.lineTo(209,134);ctx.stroke();ctx
